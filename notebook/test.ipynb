# %%
print("all ok")
# Out:
# all ok

# %%
import os
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)

print("Current:", current_dir)
print("Parent:", parent_dir)
# Out:
# Current: c:\Users\Narala Nithin\OneDrive\Desktop\ecommerce_product_assistant\notebook
# Parent: c:\Users\Narala Nithin\OneDrive\Desktop\ecommerce_product_assistant

# %%
current_dir=os.path.dirname(os.getcwd())
print(current_dir)
csv_path=os.path.join(current_dir,"data","products.csv")
print(csv_path)
# Out:
# c:\Users\Narala Nithin\OneDrive\Desktop\ecommerce_product_assistant
# c:\Users\Narala Nithin\OneDrive\Desktop\ecommerce_product_assistant\data\products.csv
